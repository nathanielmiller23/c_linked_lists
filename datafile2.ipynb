# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eac7979a-b712-418b-bd8a-af04451c1209" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eac7979a-b712-418b-bd8a-af04451c1209">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datafile2.txt to datafile2 (2).txt

# %%
df = pd.read_fwf('datafile2.txt',skiprows=49)

# %%
print(df)
# Out:
#      -3.000000 1.000000 0.0000000
# 0     6.66667E-4 28.63940 1.910962
# 1     .004166667 28.63853 1.908158
# 2     0.01250000 28.63878 1.900223
# 3     0.02083334 28.64114 1.899288
# 4     0.02916666 28.63875 1.902246
# ...                            ...
# 8263  68.84582 750.0116 0.08634269
# 8264  68.85416 750.0085 0.08634919
# 8265  68.86250 750.0114 0.08633519
# 8266  68.87084 750.0128 0.08636841
# 8267  -2.000000 1.000000 0.0000000
#
# [8268 rows x 1 columns]

# %%
pd.DataFrame(df).head()
df = pd.DataFrame('x', index=range(8268), columns=list('abc'))

# %%
df = pd.DataFrame(np.random.randn(8268, 2), index=df.index, columns=list("bc"))
df = df.cumsum()
plt.figure();
df.plot();


#a represents Time
#b represents Temp
#c represents Mass
